# %%
library(tidyverse)
library(dplyr)
# Out:
# ── Attaching core tidyverse packages ──────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.2.1     ✔ readr     2.2.0
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.3     ✔ tibble    3.3.1
# ✔ lubridate 1.9.5     ✔ tidyr     1.3.2
# ✔ purrr     1.2.2
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
nhl_players <- readRDS ("Predict NHL Breakout 26-27/nhl_players.rds")

# %%
nhl_players <- nhl_players |>
    filter(situation == "all")

nrow(nhl_players)
# Out:
# [1] 10115

# %%
nhl_players <- nhl_players |>
    select (where(~ !all(is.na(.))))

# %%
invisible(colnames(nhl_players))

# %%
nhl_clean <- nhl_players |>
    transmute(
        player_id = playerId,
        player_name = name,
        season_start = season,
        team,
        position,
        games_played, 

        total_minutes = icetime/ 60,
        average_minutes = total_minutes / games_played, 

        goals = I_F_goals, 
        primary_assists = I_F_primaryAssists, 
        secondary_assists = I_F_secondaryAssists,
        assists = primary_assists + secondary_assists,
        points = I_F_points,
    
        points_per_game = points / games_played,
        points_per_82 = points_per_game * 82
  )

# %%
nrow(nhl_clean)
# Out:
# [1] 10115

# %%
ncol(nhl_clean)
# Out:
# [1] 15

# %%
print(
    head(nhl_clean, 20),
    n = 20
    )
# Out:
# # A tibble: 20 × 15
#    player_id player_name  season_start team  position games_played total_minutes
#        <dbl> <chr>               <dbl> <chr> <chr>           <dbl>         <dbl>
#  1   8469459 Mikko Koivu          2015 MIN   C                  82        1634.
#  2   8477845 Trevor van …         2015 CHI   D                  82        1639.
#  3   8470724 Kyle Quincey         2015 DET   D                  47         929.
#  4   8476887 Filip Forsb…         2015 NSH   L                  82        1562.
#  5   8466285 Brian Campb…         2015 FLA   D                  82        1827.
#  6   8474052 Chris Terry          2015 CAR   L                  68         767.
#  7   8478393 Kyle Baun            2015 CHI   R                   2          18.1
#  8   8474037 James van R…         2015 TOR   L                  40         711.
#  9   8476449 Scott Harri…         2015 TOR   D                  15         196.
# ...

# %%
player_bios <- read_csv(
    "Predict NHL breakout 26-27/player_bios.csv",
    show_col_types = FALSE
    )
names(player_bios)
head(player_bios)
# Out:
#  [1] "playerId"        "name"            "position"        "team"
#  [5] "birthDate"       "weight"          "height"          "nationality"
#  [9] "shootsCatches"   "primaryNumber"   "primaryPosition"
#   playerId name          position team birthDate  weight height nationality
# 1 8478421  A.J. Greer    L        FLA  1996-12-14 210    6' 3"  CAN
# 2 8477180  Aaron Dell    G        SJS  1989-05-04 205    6' 0"  CAN
# 3 8465992  Aaron Downey  R        DET  1974-08-27 215    6' 1"  CAN
# 4 8477932  Aaron Ekblad  D        FLA  1996-02-07 220    6' 4"  CAN
# 5 8471451  Aaron Gagnon  C        WPG  1986-04-24 186    5' 11" CAN
# 6 8469534  Aaron Johnson D        BOS  1983-04-30 204    6' 1"  CAN
#   shootsCatches primaryNumber primaryPosition
# 1 L             24            L
# 2 L             30            G
# 3 R             44            R
# 4 R              5            D
# 5 R             21            C
# 6 L             72            D

# %%
player_bios_clean <- player_bios |>
    transmute(
        player_id = playerId,
        birth_date = as.Date(birthDate)
        )

# %%
nhl_clean <- nhl_clean |>
    left_join(
        player_bios_clean,
        by = "player_id"
        )

# %%
head(nhl_clean, 20)
# Out:
#    player_id player_name         season_start team position games_played
# 1  8469459   Mikko Koivu         2015         MIN  C        82
# 2  8477845   Trevor van Riemsdyk 2015         CHI  D        82
# 3  8470724   Kyle Quincey        2015         DET  D        47
# 4  8476887   Filip Forsberg      2015         NSH  L        82
# 5  8466285   Brian Campbell      2015         FLA  D        82
# 6  8474052   Chris Terry         2015         CAR  L        68
# 7  8478393   Kyle Baun           2015         CHI  R         2
# 8  8474037   James van Riemsdyk  2015         TOR  L        40
# 9  8476449   Scott Harrington    2015         TOR  D        15
# 10 8475727   Ryan Spooner        2015         BOS  C        80
# 11 8475728   Johan Larsson       2015         BUF  C        74
# 12 8477504   Josh Morrissey      2015         WPG  D         1
# 13 8477006   Christoph Bertschy  2015         MIN  C         3
# 14 8476370   Blake Pietila       2015         N.J  L         7
# ...

# %%
nhl_clean <- nhl_clean |>
    mutate(
        season_date = as.Date (
            paste0(season_start, "-10-01")
            ),

        age = as.numeric (
            difftime(
                season_date,
                birth_date,
                units = "days"
                )
            ) / 365.25
        )
head(nhl_clean, 20)
# Out:
#    player_id player_name         season_start team position games_played
# 1  8469459   Mikko Koivu         2015         MIN  C        82
# 2  8477845   Trevor van Riemsdyk 2015         CHI  D        82
# 3  8470724   Kyle Quincey        2015         DET  D        47
# 4  8476887   Filip Forsberg      2015         NSH  L        82
# 5  8466285   Brian Campbell      2015         FLA  D        82
# 6  8474052   Chris Terry         2015         CAR  L        68
# 7  8478393   Kyle Baun           2015         CHI  R         2
# 8  8474037   James van Riemsdyk  2015         TOR  L        40
# 9  8476449   Scott Harrington    2015         TOR  D        15
# 10 8475727   Ryan Spooner        2015         BOS  C        80
# 11 8475728   Johan Larsson       2015         BUF  C        74
# 12 8477504   Josh Morrissey      2015         WPG  D         1
# 13 8477006   Christoph Bertschy  2015         MIN  C         3
# 14 8476370   Blake Pietila       2015         N.J  L         7
# ...

# %%
nrow(head(nhl_clean, 20))
# Out:
# [1] 20

# %%
nhl_clean |>
    filter(is.na(age))|>
    distinct(player_id, player_name)
# Out:
#    player_id player_name
# 1  8478393   Kyle Baun
# 2  8475247   Michael Latta
# 3  8469490   Tim Jackman
# 4  8470230   Daniel Paille
# 5  8471996   Bracken Kearns
# 6  8467514   Pavel Datsyuk
# 7  8476404   Andy Andreoff
# 8  8478584   Vojtech Mozik
# 9  8470852   Matt Moulson
# 10 8473565   Brian Strait
# 11 8471490   Adam Cracknell
# 12 8475161   Chris Brown
# 13 8471245   Dave Bolland
# 14 8475829   John Ramage
# 15 8477392   Hudson Fasching
# 16 8475759   Brandon Gormley
# 17 8473426   Mike Weber
# 18 8478371   Matt Lorito
# 19 8476619   Zack Mitchell
# 20 8477634   Trevor Murphy
# 21 8475328   Ben Sexton
# 22 8478911   Matt Roy
# 23 8479439   Jacob MacDonald
# 24 8481479   Brogan Rafferty
# 25 8481481   Blake Lizotte
# 26 8479330   Brandon Gignac
# 27 8479414   Nathan Bastian
# 28 8478975   Mason Marchment
# 29 8481515   Danil Yurtaykin
# 30 8479367   William Lockwood
# ⋮  ⋮         ⋮
# 38 8483641   Anton Levtchi
# 39 8483619   Filip Roos
# 40 8482176   Wyatt Kaiser
# ...

# %%
nhl_clean |>
    filter(is.na(age))|>
    select(
        player_id,
        player_name,
        season_start,
        team
        )
# Out:
#     player_id player_name             season_start team
# 1   8478393   Kyle Baun               2015         CHI
# 2   8475247   Michael Latta           2015         WSH
# 3   8469490   Tim Jackman             2015         ANA
# 4   8470230   Daniel Paille           2015         NYR
# 5   8471996   Bracken Kearns          2015         NYI
# 6   8467514   Pavel Datsyuk           2015         DET
# 7   8476404   Andy Andreoff           2015         L.A
# 8   8478584   Vojtech Mozik           2015         N.J
# 9   8470852   Matt Moulson            2015         BUF
# 10  8473565   Brian Strait            2015         NYI
# 11  8471490   Adam Cracknell          2015         EDM
# 12  8475161   Chris Brown             2015         WSH
# 13  8471245   Dave Bolland            2015         FLA
# 14  8475829   John Ramage             2015         CBJ
# 15  8477392   Hudson Fasching         2015         BUF
# 16  8475759   Brandon Gormley         2015         COL
# ...

# %%
mean(!is.na(nhl_clean$age))*100
# Out:
# [1] 98.58626

# %%
nhl_model_ready <- nhl_clean |>
    filter(!is.na(age))

#filtering out players whose age could not be matched with a player id on moneypuck

# %%
sum(is.na(nhl_model_ready$age))
# Out:
# [1] 0

# %%
summary(nhl_model_ready$age)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   18.05   23.42   26.14   26.67   29.51   45.63

# %%
nhl_model_ready |>
    arrange(age)|>
    select(player_name, season_start, age) |>
    slice_head(n = 10)
# Out:
#    player_name        season_start age
# 1  Alex Formenton     2017         18.05065
# 2  Filip Chytil       2017         18.07255
# 3  Matthew Schaefer   2025         18.07255
# 4  Jett Luchanko      2024         18.11362
# 5  Quinton Byfield    2020         18.11910
# 6  Clayton Keller     2016         18.17659
# 7  Connor Bedard      2023         18.20671
# 8  Jesperi Kotkaniemi 2018         18.23682
# 9  Mikhail Sergachev  2016         18.26968
# 10 Macklin Celebrini  2024         18.30253

# %%
nhl_outcomes <- nhl_model_ready |>
    arrange(player_id, season_start) |>
    group_by(player_id) |>
    mutate (
        next_season = lead(season_start),
        next_games_played = lead(games_played),
        next_points_per_82 = lead(points_per_82)
        ) |>
ungroup()

##starts with the whole dataset not just active cases

# %%
nhl_outcomes <- nhl_outcomes |>
    filter(next_season == season_start + 1) |>
##removes cases where players missed a season before returning

# %%
nhl_outcomes <- nhl_outcomes |>
    filter(
        games_played >= 30,
        next_games_played >= 30
        )

##minimum 30 games per season requirement in order for stats to be relevant

# %%
nhl_outcomes <- nhl_outcomes |>
    mutate(
        points_increase = 
        next_points_per_82 - points_per_82,

        percentage_increase = if_else(
            points_per_82 > 0,
            points_increase / points_per_82,
            NA_real_
            ),
        breakout = if_else (
            points_increase >= 15 &
            percentage_increase >= 0.25,
            1L,
            0L
            )
        ) |>
    filter(!is.na(breakout))

#define a breakout by putting it into a binary system
# 1  = breakout
# 0 = no breakout

# %%
nhl_outcomes |>
    count(breakout) |>
    mutate(percentage = n / sum(n) * 100)
# Out:
#   breakout n    percentage
# 1 0        4670 89.70419
# 2 1         536 10.29581

# %%
training_data <- nhl_outcomes |>
  filter(season_start <= 2022)

validation_data <- nhl_outcomes |>
  filter(season_start == 2023)

testing_data <- nhl_outcomes |>
  filter(season_start == 2024)

prediction_data <- nhl_model_ready |>
  filter(season_start == 2025)

# %%
range(training_data$season_start)
unique(validation_data$season_start)
unique(testing_data$season_start)
unique(prediction_data$season_start)
# Out:
# [1] 2015 2022
# [1] 2023
# [1] 2024
# [1] 2025

# %%
tibble(
  dataset = c(
    "Training",
    "Validation",
    "Testing",
    "Prediction"
  ),
  rows = c(
    nrow(training_data),
    nrow(validation_data),
    nrow(testing_data),
    nrow(prediction_data)
  )
)

#looking to build a model with past information, validate on a later season
#test on a new season and generate real predictions for 2026/2027 season
# Out:
#   dataset    rows
# 1 Training   4112
# 2 Validation  552
# 3 Testing     542
# 4 Prediction  904

# %%
saveRDS(nhl_outcomes, 
        "Predict NHL Breakout 26-27/nhl_outcomes.rds"
        )
